# %% [markdown]
# # Bluk insert
#
# 다량의 document를 효율적으로 입력하기 위한 방법을 학습합니다.</br>
# document를 개개별로 입력하는 것보다 수행속도가 빠르며, 불필요한 오버헤드가 없습니다.

# %% [markdown]
# ### library 및 변수 셋팅

# %%
import sys
import json
import requests
import pandas as pd
from dotenv import load_dotenv
from azure.identity import DefaultAzureCredential
from azure.core.credentials import AzureKeyCredential
from azure.search.documents.indexes import SearchIndexClient
from azure.search.documents import SearchClient
from azure.search.documents.indexes.models import (
    ComplexField,
    SimpleField,
    SearchFieldDataType,
    SearchableField,
    SearchIndex
)
import os

load_dotenv()

endpoint = os.getenv("AZURE_SEARCH_SERVICE_ENDPOINT")
credential = AzureKeyCredential(os.getenv("AZURE_SEARCH_ADMIN_KEY")) if os.getenv("AZURE_SEARCH_ADMIN_KEY") else DefaultAzureCredential()

index_name = "good-books"

# index의 schema를 json 파일에 저장하여 놓았습니다.
index_schema_json_file = "./data/good-books-index.json"

# 데이터 파일
books_url = "https://raw.githubusercontent.com/Azure-Samples/azure-search-sample-data/main/good-books/books.csv"
batch_size = 1000

# %% [markdown]
# ### Index 생성

# %%
# index schema 
with open(index_schema_json_file) as json_file:
    index_schema = json.load(json_file)

# Index 생성
index = SearchIndex(name=index_name, fields=index_schema['fields'], suggesters=index_schema['suggesters'])
index_client = SearchIndexClient(endpoint=endpoint, credential=credential)
result = index_client.create_or_update_index(index)
print(f' {result.name} 생성')
# Out:
#  good-books 생성

# %% [markdown]
# ### bulk insert
#
# [update_documents](https://learn.microsoft.com/ko-kr/python/api/azure-search-documents/azure.search.documents.searchclient?view=azure-python#azure-search-documents-searchclient-upload-documents) 함수를 사용하여 bulk insert를 수행합니다.

# %%
# 데이터 파일 로드 - 10000 rows
df = pd.read_csv(books_url)
df.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13                      authors  original_publication_year  \
# 0  9.780000e+12              Suzanne Collins                     2008.0
# 1  9.780000e+12  J.K. Rowling, Mary GrandPré                     1997.0
# 2  9.780000e+12              Stephenie Meyer                     2005.0
# 3  9.780000e+12                   Harper Lee                     1960.0
# 4  9.780000e+12          F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... ratings_count  \
# 0                          The Hunger Games  ...       4780653
# 1  Harry Potter and the Philosopher's Stone  ...       4602479
# 2                                  Twilight  ...       3866839
# 3                     To Kill a Mockingbird  ...       3198671
# 4                          The Great Gatsby  ...       2683664
#
#   work_ratings_count  work_text_reviews_count  ratings_1  ratings_2  \
# 0            4942365                   155254      66715     127936
# 1            4800065                    75867      75504     101676
# 2            3916824                    95009     456191     436802
# 3            3340896                    72586      60427     117415
# 4            2773745                    51992      86236     197621
#
#    ratings_3  ratings_4  ratings_5  \
# 0     560092    1481305    2706317
# 1     455024    1156318    3011543
# 2     793319     875073    1355439
# 3     446835    1001952    1714267
# 4     606158     936012     947718
#
#                                            image_url  \
# 0  https://images.gr-assets.com/books/1447303603m...
# 1  https://images.gr-assets.com/books/1474154022m...
# 2  https://images.gr-assets.com/books/1361039443m...
# 3  https://images.gr-assets.com/books/1361975680m...
# 4  https://images.gr-assets.com/books/1490528560m...
#
#                                      small_image_url
# 0  https://images.gr-assets.com/books/1447303603s...
# 1  https://images.gr-assets.com/books/1474154022s...
# 2  https://images.gr-assets.com/books/1361039443s...
# 3  https://images.gr-assets.com/books/1361975680s...
# 4  https://images.gr-assets.com/books/1490528560s...
#
# [5 rows x 23 columns]

# %%
# csv 데이터 -> json으로 변환
books_data_json = json.loads(df.to_json(orient="records"))

batch_array = []
count = 0
batch_counter = 0

search_client = SearchClient(
    endpoint=endpoint,
    credential=credential,
    index_name=index_name)

# 원하는 형태로 변경하기 위해 데이터 변경을 합니다.
for i in books_data_json:
    count += 1
    batch_array.append(
        {
            "id": str(i["book_id"]),
            "goodreads_book_id": int(i["goodreads_book_id"]),
            "best_book_id": int(i["best_book_id"]),
            "work_id": int(i["work_id"]),
            "books_count": i["books_count"] if i["books_count"] else 0,
            "isbn": str(i["isbn"]),
            "isbn13": str(i["isbn13"]),
            "authors": i["authors"].split(",") if i["authors"] else None,
            "original_publication_year": int(i["original_publication_year"])
            if i["original_publication_year"]
            else 0,
            "original_title": i["original_title"],
            "title": i["title"],
            "language_code": i["language_code"],
            "average_rating": int(i["average_rating"])
            if i["average_rating"]
            else 0,
            "ratings_count": int(i["ratings_count"]) if i["ratings_count"] else 0,
            "work_ratings_count": int(i["work_ratings_count"])
            if i["work_ratings_count"]
            else 0,
            "work_text_reviews_count": i["work_text_reviews_count"]
            if i["work_text_reviews_count"]
            else 0,
            "ratings_1": int(i["ratings_1"]) if i["ratings_1"] else 0,
            "ratings_2": int(i["ratings_2"]) if i["ratings_2"] else 0,
            "ratings_3": int(i["ratings_3"]) if i["ratings_3"] else 0,
            "ratings_4": int(i["ratings_4"]) if i["ratings_4"] else 0,
            "ratings_5": int(i["ratings_5"]) if i["ratings_5"] else 0,
            "image_url": i["image_url"],
            "small_image_url": i["small_image_url"],
        }
    )

    # 1000 레코드씩 입력 합니다.
    if count % batch_size == 0:
        search_client.upload_documents(documents=batch_array)
        batch_counter += 1

        print(f"Batch sent! - #{batch_counter}")
        batch_array = []

if len(batch_array) > 0:
    search_client.upload_documents(documents=batch_array)
    batch_counter += 1

    print(f"Final batch sent! - #{batch_counter}")

print("Done!")
# Out:
# Batch sent! - #1
# Batch sent! - #2
# Batch sent! - #3
# Batch sent! - #4
# Batch sent! - #5
# Batch sent! - #6
# Batch sent! - #7
# Batch sent! - #8
# Batch sent! - #9
# Batch sent! - #10
# Done!

# %% [markdown]
# ### 데이터 확인

# %%
results =  search_client.search(query_type='simple',
    search_text="*" ,
    top=10,
    include_total_count=True)

# 검색 결과로 HotelName, Description 필드와 함께 검색 score도 표시합니다. 
print ('Total Documents Matching Query:', results.get_count())
for result in results:
    print(result)
# Out:
# Total Documents Matching Query: 10000
# {'ratings_5': 10036, 'ratings_2': 733, 'original_title': 'Homage to Catalonia', 'work_text_reviews_count': 1500, 'image_url': 'https://images.gr-assets.com/books/1394868278m/9646.jpg', 'language_code': 'eng', 'isbn': '156421178', 'work_ratings_count': 25881, 'ratings_1': 176, 'books_count': 151, 'authors': ['George Orwell', ' Lionel Trilling'], 'original_publication_year': 1938, 'goodreads_book_id': 9646, 'title': 'Homage to Catalonia', 'work_id': 2566499, 'best_book_id': 9646, 'id': '4004', 'isbn13': '9780000000000.0', 'ratings_4': 10529, 'small_image_url': 'https://images.gr-assets.com/books/1394868278s/9646.jpg', 'ratings_3': 4407, 'average_rating': 4.0, 'ratings_count': 22227, '@search.score': 1.0, '@search.reranker_score': None, '@search.highlights': None, '@search.captions': None}
# {'ratings_5': 12300, 'ratings_2': 1867, 'original_title': 'The Girl In The Ice', 'work_text_reviews_count': 2987, 'image_url': 'https://images.gr-assets.com/books/1450369120m/28233082.jpg', 'language_code': 'eng', 'isbn': 'None', 'work_ratings_count': 37924, 'ratings_1': 930, 'books_count': 27, 'authors': ['Robert Bryndza'], 'original_publication_year': 2016, 'goodreads_book_id': 28233082, 'title': 'The Girl In The Ice (Detective Erika Foster, #1)', 'work_id': 48263544, 'best_book_id': 28233082, 'id': '4011', 'isbn13': 'None', 'ratings_4': 15080, 'small_image_url': 'https://images.gr-assets.com/books/1450369120s/28233082.jpg', 'ratings_3': 7747, 'average_rating': 3.0, 'ratings_count': 33739, '@search.score': 1.0, '@search.reranker_score': None, '@search.highlights': None, '@search.captions': None}
# {'ratings_5': 2108, 'ratings_2': 3416, 'original_title': 'A Hologram for the King', 'work_text_reviews_count': 2774, 'image_url': 'https://images.gr-assets.com/books/1337179987m/13722902.jpg', 'language_code': 'eng', 'isbn': '193636574X', 'work_ratings_count': 22851, 'ratings_1': 759, 'books_count': 62, 'authors': ['Dave Eggers'], 'original_publication_year': 2012, 'goodreads_book_id': 13722902, 'title': 'A Hologram for the King', 'work_id': 19355962, 'best_book_id': 13722902, 'id': '4020', 'isbn13': '9780000000000.0', 'ratings_4': 7439, 'small_image_url': 'https://images.gr-assets.com/books/1337179987s/13722902.jpg', 'ratings_3': 9129, 'average_rating': 3.0, 'ratings_count': 20094, '@search.score': 1.0, '@search.reranker_score': None, '@search.highlights': None, '@search.captions': None}
# {'ratings_5': 8724, 'ratings_2': 697, 'original_title': 'Morality for Beautiful Girls', 'work_text_reviews_count': 1507, 'image_url': 'https://images.gr-assets.com/books/1379303019m/7035.jpg', 'language_code': 'eng', 'isbn': '1400031362', 'work_ratings_count': 32422, 'ratings_1': 74, 'books_count': 66, 'authors': ['Alexander McCall Smith'], 'original_publication_year': 2001, 'goodreads_book_id': 7035, 'title': "Morality for Beautiful Girls (No. 1 Ladies' Detective Agency, #3)", 'work_id': 5913092, 'best_book_id': 7035, 'id': '4027', 'isbn13': '9780000000000.0', 'ratings_4': 14913, 'small_image_url': 'https://images.gr-assets.com/books/1379303019s/7035.jpg', 'ratings_3': 8014, 'average_rating': 3.0, 'ratings_count': 29574, '@search.score': 1.0, '@search.reranker_score': None, '@search.highlights': None, '@search.captions': None}
# {'ratings_5': 11819, 'ratings_2': 720, 'original_title': 'Anne Frank: Beyond the Diary - A Photographic Remembrance', 'work_text_reviews_count': 181, 'image_url': 'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png', 'language_code': None, 'isbn': '140369260', 'work_ratings_count': 22852, 'ratings_1': 499, 'books_count': 12, 'authors': ['Ruud van der Rol', ' Rian Verhoeven', ' Anna Quindlen', ' Anne Frank', ' Tony Langham', ' Plym Peters'], 'original_publication_year': 1992, 'goodreads_book_id': 5508, 'title': 'Anne Frank: Beyond the Diary - A Photographic Remembrance', 'work_id': 318156, 'best_book_id': 5508, 'id': '4043', 'isbn13': '9780000000000.0', 'ratings_4': 6564, 'small_image_url': 'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png', 'ratings_3': 3250, 'average_rating': 4.0, 'ratings_count': 22725, '@search.score': 1.0, '@search.reranker_score': None, '@search.highlights': None, '@search.captions': None}
# {'ratings_5': 4689, 'ratings_2': 5052, 'original_title': 'Half Girlfriend', 'work_text_reviews_count': 2067, 'image_url': 'https://images.gr-assets.com/books/1407223058m/22874559.jpg', 'language_code': 'en-CA', 'isbn': '8129135728', 'work_ratings_count': 27146, 'ratings_1': 3207, 'books_count': 8, 'authors': ['Chetan Bhagat'], 'original_publication_year': 2014, 'goodreads_book_id': 22874559, 'title': 'Half Girlfriend', 'work_id': 42438620, 'best_book_id': 22874559, 'id': '4045', 'isbn13': '9790000000000.0', 'ratings_4': 6343, 'small_image_url': 'https://images.gr-assets.com/books/1407223058s/22874559.jpg', 'ratings_3': 7855, 'average_rating': 3.0, 'ratings_count': 22082, '@search.score': 1.0, '@search.reranker_score': None, '@search.highlights': None, '@search.captions': None}
# {'ratings_5': 4133, 'ratings_2': 3379, 'original_title': 'Saving Fish from Drowning: A Novel', 'work_text_reviews_count': 2586, 'image_url': 'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png', 'language_code': 'eng', 'isbn': '034546401X', 'work_ratings_count': 26060, 'ratings_1': 1247, 'books_count': 64, 'authors': ['Amy Tan'], 'original_publication_year': 2005, 'goodreads_book_id': 9503, 'title': 'Saving Fish from Drowning', 'work_id': 1223399, 'best_book_id': 9503, 'id': '4057', 'isbn13': '9780000000000.0', 'ratings_4': 8374, 'small_image_url': 'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png', 'ratings_3': 8927, 'average_rating': 3.0, 'ratings_count': 24579, '@search.score': 1.0, '@search.reranker_score': None, '@search.highlights': None, '@search.captions': None}
# {'ratings_5': 9607, 'ratings_2': 1913, 'original_title': 'The Eight', 'work_text_reviews_count': 2199, 'image_url': 'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png', 'language_code': 'eng', 'isbn': '345366239', 'work_ratings_count': 27460, 'ratings_1': 762, 'books_count': 102, 'authors': ['Katherine Neville'], 'original_publication_year': 1988, 'goodreads_book_id': 113310, 'title': 'The Eight (The Eight #1)', 'work_id': 268923, 'best_book_id': 113310, 'id': '4067', 'isbn13': '9780000000000.0', 'ratings_4': 9488, 'small_image_url': 'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png', 'ratings_3': 5690, 'average_rating': 3.0, 'ratings_count': 22928, '@search.score': 1.0, '@search.reranker_score': None, '@search.highlights': None, '@search.captions': None}
# {'ratings_5': 9958, 'ratings_2': 1790, 'original_title': 'A Long Way From Chicago', 'work_text_reviews_count': 2041, 'image_url': 'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png', 'language_code': 'eng', 'isbn': '142401102', 'work_ratings_count': 28541, 'ratings_1': 834, 'books_count': 31, 'authors': ['Richard Peck'], 'original_publication_year': 1998, 'goodreads_book_id': 39963, 'title': 'A Long Way from Chicago (A Long Way from Chicago, #1)', 'work_id': 1207111, 'best_book_id': 39963, 'id': '4094', 'isbn13': '9780000000000.0', 'ratings_4': 9708, 'small_image_url': 'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png', 'ratings_3': 6251, 'average_rating': 3.0, 'ratings_count': 27642, '@search.score': 1.0, '@search.reranker_score': None, '@search.highlights': None, '@search.captions': None}
# {'ratings_5': 8183, 'ratings_2': 1178, 'original_title': ' Innocent Traitor', 'work_text_reviews_count': 1589, 'image_url': 'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png', 'language_code': 'eng', 'isbn': '345494857', 'work_ratings_count': 26722, 'ratings_1': 384, 'books_count': 33, 'authors': ['Alison Weir'], 'original_publication_year': 2006, 'goodreads_book_id': 111218, 'title': 'Innocent Traitor', 'work_id': 910444, 'best_book_id': 111218, 'id': '4129', 'isbn13': '9780000000000.0', 'ratings_4': 10806, 'small_image_url': 'https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png', 'ratings_3': 6171, 'average_rating': 3.0, 'ratings_count': 24976, '@search.score': 1.0, '@search.reranker_score': None, '@search.highlights': None, '@search.captions': None}
